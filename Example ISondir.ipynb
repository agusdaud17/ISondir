# %%
import ISondir

# %%
s1 = ISondir.Single(id_='CPT-01')
s1.read_excel('raw_data.xlsx')
s1.setGWL(z=1)
s1.solve_basic()
s1.solve_parameters()

# %%
s1.raw_plot()

# %%
s1.basic_plot()

# %%
s1.plot_SBTn()

# %%
s1.plot_rigidityIndex()

# %%
s1.soil_profil()

# %%
s1.plot_norm()

# %%
s1.estimation_plot1()

# %%
s1.estimation_plot2()

# %%
s1.estimation_plot3()
